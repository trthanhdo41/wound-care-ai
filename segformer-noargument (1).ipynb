# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0566.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0133.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0006.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0516.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0003.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0217.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0816.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0337.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0835.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0096.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0451.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0301.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0947.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0405.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0341.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0208.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0369.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0412.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0291.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0007.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0971.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0834.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0375.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0712.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0763.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0940.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0439.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0475.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0180.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0802.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0078.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0146.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0355.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0517.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0122.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0905.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0974.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0339.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0985.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0047.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0612.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0881.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0588.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0958.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0809.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0824.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0450.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0715.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0948.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0717.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0108.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0545.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0644.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0548.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0303.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0259.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0559.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0033.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0867.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0964.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/1003.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0004.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0466.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0603.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0813.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0124.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0456.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0647.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0390.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0849.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0652.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0058.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0865.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0577.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0979.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0494.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0874.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0833.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0046.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/1009.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0447.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0706.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0721.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0030.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0847.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0417.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0887.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0904.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0607.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0557.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0233.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0143.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0796.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0134.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0496.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0363.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0128.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0213.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0961.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0901.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0334.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0604.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0284.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0192.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0438.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0126.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0322.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0470.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0349.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0880.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0511.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0541.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0365.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0010.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0483.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0235.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0201.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0973.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0136.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0651.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0001.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0068.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0830.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0806.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0528.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0543.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0954.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0079.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0002.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0842.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0533.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0728.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0616.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0008.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0657.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0245.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0085.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0278.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0256.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0525.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0900.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0190.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0582.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0262.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0682.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0820.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0580.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0937.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0057.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0738.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0356.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0203.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0642.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0300.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0289.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0251.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0025.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0107.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0679.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0504.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0591.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0949.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0615.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0005.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0276.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0326.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0869.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0922.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0376.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0955.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0485.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0177.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0549.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0565.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0757.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0082.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0407.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0638.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0674.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0798.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0730.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0089.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0009.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0429.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0906.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0382.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0627.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0745.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0976.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0781.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0503.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0416.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0729.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0946.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0398.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0164.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0437.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0211.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0062.png
# /kaggle/input/train-thesis/Dataset (S/validation/labels/0571.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0566.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0133.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0006.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0516.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0003.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0217.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0816.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0337.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0835.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0096.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0451.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0301.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0947.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0405.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0341.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0208.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0369.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0412.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0291.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0007.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0971.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0834.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0375.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0712.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0763.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0940.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0439.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0475.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0180.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0802.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0078.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0146.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0355.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0517.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0122.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0905.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0974.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0339.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0985.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0047.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0612.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0881.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0588.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0958.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0809.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0824.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0450.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0715.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0948.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0717.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0108.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0545.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0644.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0548.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0303.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0259.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0559.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0033.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0867.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0964.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/1003.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0004.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0466.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0603.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0813.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0124.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0456.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0647.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0390.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0849.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0652.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0058.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0865.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0577.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0979.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0494.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0874.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0833.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0046.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/1009.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0447.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0706.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0721.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0030.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0847.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0417.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0887.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0904.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0607.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0557.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0233.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0143.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0796.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0134.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0496.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0363.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0128.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0213.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0961.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0901.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0334.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0604.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0284.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0192.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0438.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0126.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0322.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0470.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0349.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0880.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0511.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0541.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0365.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0010.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0483.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0235.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0201.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0973.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0136.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0651.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0001.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0068.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0830.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0806.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0528.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0543.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0954.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0079.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0002.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0842.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0533.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0728.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0616.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0008.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0657.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0245.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0085.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0278.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0256.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0525.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0900.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0190.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0582.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0262.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0682.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0820.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0580.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0937.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0057.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0738.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0356.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0203.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0642.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0300.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0289.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0251.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0025.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0107.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0679.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0504.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0591.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0949.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0615.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0005.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0276.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0326.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0869.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0922.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0376.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0955.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0485.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0177.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0549.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0565.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0757.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0082.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0407.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0638.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0674.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0798.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0730.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0089.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0009.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0429.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0906.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0382.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0627.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0745.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0976.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0781.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0503.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0416.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0729.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0946.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0398.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0164.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0437.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0211.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0062.png
# /kaggle/input/train-thesis/Dataset (S/validation/images/0571.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1343.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1037.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1337.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1048.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1176.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1312.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1156.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1348.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1266.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1206.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1064.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1334.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1123.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1168.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1118.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1326.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1036.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1445.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1307.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1071.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1381.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1269.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1018.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1220.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1469.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1333.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1405.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1137.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1135.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1279.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1339.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1199.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1283.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1108.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1322.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1240.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1130.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1347.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1212.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1165.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1361.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1338.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1055.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1282.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1039.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1423.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1324.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1047.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1288.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1285.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1054.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1121.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1038.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1078.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1238.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1163.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1379.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1139.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1246.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1029.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1073.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1157.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1437.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1390.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1276.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1291.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1109.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1144.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1143.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1404.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1105.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1300.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1216.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1471.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1235.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1446.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1459.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1442.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1083.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1136.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1190.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1271.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1284.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1313.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1467.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1089.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1115.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1253.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1119.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1306.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1299.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1014.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1448.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1287.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1152.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1239.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1213.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1183.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1476.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1470.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1277.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1439.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1204.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1114.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1382.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1419.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1196.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1465.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1022.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1355.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1260.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1020.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1259.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1473.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1358.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1460.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1171.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1418.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1217.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1357.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1233.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1319.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1232.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1321.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1221.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1075.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1444.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1298.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1254.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1399.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1173.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1098.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1443.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1421.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1131.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1242.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1406.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1412.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1296.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1318.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1205.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1046.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1050.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1342.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1310.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1140.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1427.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1059.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1475.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1011.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1061.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1159.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1028.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1450.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1466.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1066.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1316.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1086.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1359.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1194.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1158.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1198.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1305.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1016.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1464.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1112.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1462.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1021.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1174.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1278.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1065.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1303.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1370.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1060.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1237.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1101.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1389.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1332.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1024.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1042.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1363.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1397.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1331.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1177.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1416.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1222.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1395.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1058.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1110.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1034.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1365.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1074.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1267.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1160.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1350.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1373.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1211.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1396.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1281.png
# /kaggle/input/train-thesis/Dataset (S/test/images/1424.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0115.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0050.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0501.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0263.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0563.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0693.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0857.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0013.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0052.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0394.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0178.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0273.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0314.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0139.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0460.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0148.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0242.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0185.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0740.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0889.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0226.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0053.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0099.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0340.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0453.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0670.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0274.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0699.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0968.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0295.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0512.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0039.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0480.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0266.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0044.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/1000.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0576.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0311.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0486.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0360.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0153.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0017.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0646.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/1004.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0433.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0529.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0759.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0950.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0286.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0766.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0118.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0804.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0071.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0704.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0752.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0683.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0686.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0316.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0872.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0041.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0472.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0697.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0011.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0495.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0866.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0077.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0427.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0119.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0846.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0884.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0345.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0562.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0424.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0711.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0419.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0671.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0479.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0521.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0459.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0067.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0202.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0876.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/1010.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0194.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0189.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0662.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0163.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0807.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0761.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0737.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0196.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0780.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0573.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0561.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0239.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0675.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0249.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0821.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0393.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0418.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0127.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0152.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0631.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0554.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0445.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0910.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0608.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0157.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0304.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0137.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0917.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0667.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0083.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0444.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0069.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0600.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0801.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0348.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0617.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0590.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0914.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0275.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0351.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0378.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0655.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0140.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0825.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0392.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0072.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0864.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0297.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0294.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0513.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0086.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0726.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0487.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0613.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0506.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0229.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0090.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0972.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0702.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0628.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0527.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0342.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0464.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0396.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0967.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0568.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0742.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0073.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0640.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0491.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0218.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/1006.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0920.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0618.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0589.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0492.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0330.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0101.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0210.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0066.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0592.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0353.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0856.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0457.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0106.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0928.png
# /kaggle/input/train-thesis/Dataset (S/train/labels/0117.png
# ...
# /kaggle/input/train-thesis/Dataset (S/train/images/0336.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0045.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0567.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0408.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0555.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0431.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0471.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0585.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0279.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0537.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0094.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0733.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0586.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0335.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0155.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0100.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0197.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0121.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0840.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0473.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0775.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0243.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0832.png
# /kaggle/input/train-thesis/Dataset (S/train/images/1007.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0700.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0484.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0465.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0959.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0755.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0414.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0481.png
# /kaggle/input/train-thesis/Dataset (S/train/images/1001.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0064.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0610.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0727.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0673.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0329.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0785.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0882.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0430.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0894.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0347.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0061.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0443.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0746.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0381.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0764.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0814.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0216.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0817.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0509.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0791.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0149.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0626.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0182.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0860.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0574.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0154.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0863.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0705.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0324.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0215.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0725.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0896.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0040.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0611.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0389.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0247.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0810.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0750.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0630.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0093.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0377.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0774.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0028.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0605.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0400.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0505.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0436.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0174.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0878.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0912.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0676.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0786.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0741.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0442.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0547.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0664.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0415.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0081.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0691.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0063.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0423.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0579.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0993.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0692.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0160.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0762.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0102.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0488.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0092.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0794.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0331.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0186.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0815.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0191.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0343.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0477.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0019.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0354.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0449.png
# /kaggle/input/train-thesis/Dataset (S/train/images/1002.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0455.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0788.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0818.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0614.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0366.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0758.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0542.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0172.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0927.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0135.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0799.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0678.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0716.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0909.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0747.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0240.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0027.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0639.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0204.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0991.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0879.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0404.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0131.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0970.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0036.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0098.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0943.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0368.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0170.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0777.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0060.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0097.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0854.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0539.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0851.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0957.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0112.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0109.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0151.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0531.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0200.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0145.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0701.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0435.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0953.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0399.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0463.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0482.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0159.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0769.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0361.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0888.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0942.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0357.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0280.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0935.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0422.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0891.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0364.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0302.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0395.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0732.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0848.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0637.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0129.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0380.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0493.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0831.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0188.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0502.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0930.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0260.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0918.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0080.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0564.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0268.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0668.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0625.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0659.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0877.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0859.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0308.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0850.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0362.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0744.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0723.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0184.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0104.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0873.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0277.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0065.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0952.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0932.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0977.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0622.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0635.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0141.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0658.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0250.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0267.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0535.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0526.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0346.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0269.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0287.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0653.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0312.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0257.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0663.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0845.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0232.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0458.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0897.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0855.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0916.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0281.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0962.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0660.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0338.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0387.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0572.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0641.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0383.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0173.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0219.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0601.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0168.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0720.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0264.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0309.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0924.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0026.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0059.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0756.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0789.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0158.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0227.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0963.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0551.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0934.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0695.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0220.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0252.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0782.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0015.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0938.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0861.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0578.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0306.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0931.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0222.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0672.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0544.png
# /kaggle/input/train-thesis/Dataset (S/train/images/0575.png

# %% [markdown]
# # Cell 1: Cài đặt & import thư viện cần thiết

# %%
# !pip install -q segmentation-models-pytorch albumentations timm

import os
import cv2
import random
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import albumentations as A
from albumentations.pytorch import ToTensorV2

import segmentation_models_pytorch as smp

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 89.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Using device: cuda

# %% [markdown]
# # Cell 2: Cấu hình + tự động xác định DATA_DIR và thư mục masks linh hoạt (no augmentation)

# %%
class CFG:
    IMG_SIZE = 512
    EPOCHS = 80
    BATCH_SIZE = 4
    LR = 1e-4
    NUM_WORKERS = 2
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

import os
from glob import glob

# 1) Tìm thư mục gốc có cấu trúc .../train/images
ROOT_SEARCH = "/kaggle/input/train-thesis"

candidate_roots = []
for root, dirs, files in os.walk(ROOT_SEARCH):
    norm_root = root.replace("\\", "/")
    if norm_root.endswith("/train/images"):
        dataset_root = norm_root.rsplit("/train/images", 1)[0]
        candidate_roots.append(dataset_root)

candidate_roots = sorted(set(candidate_roots))
print("Candidate DATA_DIR found:", candidate_roots)

if len(candidate_roots) == 0:
    raise FileNotFoundError(
        "Không tìm thấy thư mục train/images trong /kaggle/input/thesis. Kiểm tra lại cấu trúc dataset."
    )

DATA_DIR = candidate_roots[0]
print("Using DATA_DIR:", DATA_DIR)

# 2) Hàm tìm thư mục mask phù hợp (mask / masks / labels / segmentation...)
def find_mask_dir(split: str):
    split_dir = os.path.join(DATA_DIR, split)
    if not os.path.exists(split_dir):
        raise FileNotFoundError(f"Không tồn tại thư mục split: {split_dir}")
    
    # Ưu tiên thư mục tên chứa 'mask' hoặc 'label'
    candidates = []
    for name in os.listdir(split_dir):
        path = os.path.join(split_dir, name)
        if os.path.isdir(path):
            low = name.lower()
            if "mask" in low or "label" in low or "seg" in low:
                candidates.append(path)
    
    # Nếu không tìm thấy, fallback về 'masks'
    if not candidates:
        default_dir = os.path.join(split_dir, "masks")
        if os.path.isdir(default_dir):
            candidates.append(default_dir)
    
    if not candidates:
        print(f"[WARN] Không tìm thấy thư mục mask/label trong: {split_dir}")
        return None
    
    # Chọn candidate đầu tiên
    mask_dir = sorted(candidates)[0]
    print(f"{split} mask_dir:", mask_dir)
    return mask_dir

def get_image_mask_pairs(split: str):
    image_dir = os.path.join(DATA_DIR, split, "images")
    if not os.path.isdir(image_dir):
        print(f"[WARN] Không tìm thấy {image_dir}")
        return []
    
    mask_dir = find_mask_dir(split)
    if mask_dir is None:
        return []
    
    image_paths = sorted(glob(os.path.join(image_dir, "*")))
    exts = [".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp"]
    pairs = []

    for img_path in image_paths:
        base = os.path.splitext(os.path.basename(img_path))[0]
        found_mask = None
        for ext in exts:
            cand = os.path.join(mask_dir, base + ext)
            if os.path.exists(cand):
                found_mask = cand
                break
        if found_mask is not None:
            pairs.append((img_path, found_mask))

    print(f"{split} - found {len(pairs)} pairs")
    # In thử 3 cặp đầu để kiểm tra
    for p in pairs[:3]:
        print(" sample:", p[0], "->", p[1])
    return pairs

train_pairs = get_image_mask_pairs("train")
validation_pairs = get_image_mask_pairs("validation")

print("Total train:", len(train_pairs), "| Total val:", len(validation_pairs))
# Out:
# Candidate DATA_DIR found: ['/kaggle/input/train-thesis/Dataset (S']
# Using DATA_DIR: /kaggle/input/train-thesis/Dataset (S
# train mask_dir: /kaggle/input/train-thesis/Dataset (S/train/labels
# train - found 810 pairs
#  sample: /kaggle/input/train-thesis/Dataset (S/train/images/0011.png -> /kaggle/input/train-thesis/Dataset (S/train/labels/0011.png
#  sample: /kaggle/input/train-thesis/Dataset (S/train/images/0012.png -> /kaggle/input/train-thesis/Dataset (S/train/labels/0012.png
#  sample: /kaggle/input/train-thesis/Dataset (S/train/images/0013.png -> /kaggle/input/train-thesis/Dataset (S/train/labels/0013.png
# validation mask_dir: /kaggle/input/train-thesis/Dataset (S/validation/labels
# validation - found 200 pairs
#  sample: /kaggle/input/train-thesis/Dataset (S/validation/images/0001.png -> /kaggle/input/train-thesis/Dataset (S/validation/labels/0001.png
#  sample: /kaggle/input/train-thesis/Dataset (S/validation/images/0002.png -> /kaggle/input/train-thesis/Dataset (S/validation/labels/0002.png
#  sample: /kaggle/input/train-thesis/Dataset (S/validation/images/0003.png -> /kaggle/input/train-thesis/Dataset (S/validation/labels/0003.png
# Total train: 810 | Total val: 200

# %% [markdown]
# # Cell 3: Định nghĩa Dataset + DataLoader với transforms cơ bản (no augmentation)

# %%
class DFUSegDataset(Dataset):
    def __init__(self, pairs, img_size=CFG.IMG_SIZE):
        self.pairs = pairs
        self.img_size = img_size
        self.transform = A.Compose([
            A.Resize(self.img_size, self.img_size),
            A.Normalize(mean=(0.485, 0.456, 0.406),
                        std=(0.229, 0.224, 0.225)),
            ToTensorV2(),
        ])

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        img_path, mask_path = self.pairs[idx]

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        # chuẩn về nhị phân 0/1
        mask = (mask > 0).astype("float32")

        augmented = self.transform(image=image, mask=mask)
        image = augmented["image"]
        mask = augmented["mask"].unsqueeze(0)  # (1, H, W)

        return image, mask

# dùng train_pairs và val_pairs đã tạo ở Cell 2
train_dataset = DFUSegDataset(train_pairs, img_size=CFG.IMG_SIZE)
val_dataset = DFUSegDataset(validation_pairs, img_size=CFG.IMG_SIZE)

train_loader = DataLoader(
    train_dataset,
    batch_size=CFG.BATCH_SIZE,
    shuffle=True,
    num_workers=CFG.NUM_WORKERS,
    pin_memory=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=CFG.BATCH_SIZE,
    shuffle=False,
    num_workers=CFG.NUM_WORKERS,
    pin_memory=True,
)

print("Train batches:", len(train_loader), "| Val batches:", len(val_loader))
# Out:
# Train batches: 203 | Val batches: 50

# %% [markdown]
# # Cell 4: Định nghĩa hàm loss BCE + Dice và các metric cơ bản (Dice, IoU, Precision, Recall)

# %%
def dice_coef(pred, target, smooth=1e-5):
    pred = torch.sigmoid(pred)
    pred = (pred > 0.5).float()
    inter = (pred * target).sum(dim=(2, 3))
    union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3))
    dice = (2.0 * inter + smooth) / (union + smooth)
    return dice.mean().item()

def iou_coef(pred, target, smooth=1e-5):
    pred = torch.sigmoid(pred)
    pred = (pred > 0.5).float()
    inter = (pred * target).sum(dim=(2, 3))
    union = (pred + target - pred * target).sum(dim=(2, 3))
    iou = (inter + smooth) / (union + smooth)
    return iou.mean().item()

def bce_dice_loss(pred, target, smooth=1e-5):
    bce = F.binary_cross_entropy_with_logits(pred, target)
    pred_sig = torch.sigmoid(pred)
    inter = (pred_sig * target).sum(dim=(2, 3))
    union = pred_sig.sum(dim=(2, 3)) + target.sum(dim=(2, 3))
    dice = 1 - ((2 * inter + smooth) / (union + smooth))
    return bce + dice.mean()

print("✅ Defined: dice_coef, iou_coef, and bce_dice_loss")
# Out:
# ✅ Defined: dice_coef, iou_coef, and bce_dice_loss

# %% [markdown]
# # Cell 5: Định nghĩa hàm train và validation cho 1 epoch (no augmentation)

# %%
import gc

def train_one_epoch(model, loader, optimizer):
    model.train()
    total_loss, total_dice, total_iou = 0.0, 0.0, 0.0

    for images, masks in tqdm(loader, desc="Training", leave=False):
        images, masks = images.to(CFG.DEVICE), masks.to(CFG.DEVICE)

        optimizer.zero_grad()
        outputs = model(images)
        loss = bce_dice_loss(outputs, masks)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_dice += dice_coef(outputs, masks)
        total_iou += iou_coef(outputs, masks)

    mean_loss = total_loss / len(loader)
    mean_dice = total_dice / len(loader)
    mean_iou = total_iou / len(loader)

    return mean_loss, mean_dice, mean_iou


@torch.no_grad()
def valid_one_epoch(model, loader):
    model.eval()
    total_loss, total_dice, total_iou = 0.0, 0.0, 0.0

    for images, masks in tqdm(loader, desc="Validation", leave=False):
        images, masks = images.to(CFG.DEVICE), masks.to(CFG.DEVICE)

        outputs = model(images)
        loss = bce_dice_loss(outputs, masks)

        total_loss += loss.item()
        total_dice += dice_coef(outputs, masks)
        total_iou += iou_coef(outputs, masks)

    mean_loss = total_loss / len(loader)
    mean_dice = total_dice / len(loader)
    mean_iou = total_iou / len(loader)

    return mean_loss, mean_dice, mean_iou


def train_model(model, model_name, num_epochs=CFG.EPOCHS):
    model = model.to(CFG.DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=CFG.LR)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=5, verbose=True
    )

    best_dice = 0.0
    best_loss = np.inf

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_dice": [],
        "val_dice": [],
        "train_iou": [],
        "val_iou": [],
    }

    save_path = f"{model_name}_best_no_aug.pth"

    for epoch in range(1, num_epochs + 1):
        print(f"\n===== {model_name} | Epoch {epoch}/{num_epochs} =====")

        torch.cuda.empty_cache()
        gc.collect()

        train_loss, train_dice, train_iou = train_one_epoch(model, train_loader, optimizer)
        val_loss, val_dice, val_iou = valid_one_epoch(model, val_loader)

        scheduler.step(val_loss)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_dice"].append(train_dice)
        history["val_dice"].append(val_dice)
        history["train_iou"].append(train_iou)
        history["val_iou"].append(val_iou)

        print(
            f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
            f"Train Dice: {train_dice:.4f} | Val Dice: {val_dice:.4f} | "
            f"Train IoU: {train_iou:.4f} | Val IoU: {val_iou:.4f}"
        )

        if val_dice > best_dice:
            best_dice = val_dice
            best_loss = val_loss
            torch.save(model.state_dict(), save_path)
            print(f"✅ Saved best model: {save_path} (Val Dice: {best_dice:.4f})")

    print(f"\nBest Val Dice for {model_name}: {best_dice:.4f} (Loss: {best_loss:.4f})")
    return model, history

# %% [markdown]
# # Cell 6: Định nghĩa hàm train_model()

# %%
def train_model(model, model_name, num_epochs=CFG.EPOCHS):
    model = model.to(CFG.DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=CFG.LR)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=5, verbose=True
    )

    best_dice = 0.0
    best_loss = np.inf

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_dice": [],
        "val_dice": [],
        "train_iou": [],
        "val_iou": [],
    }

    save_path = f"{model_name}_best_no_aug.pth"

    for epoch in range(1, num_epochs + 1):
        print(f"\n===== {model_name} | Epoch {epoch}/{num_epochs} =====")

        torch.cuda.empty_cache()
        gc.collect()

        # nhận đủ 3 giá trị
        train_loss, train_dice, train_iou = train_one_epoch(model, train_loader, optimizer)
        val_loss, val_dice, val_iou = valid_one_epoch(model, val_loader)

        scheduler.step(val_loss)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_dice"].append(train_dice)
        history["val_dice"].append(val_dice)
        history["train_iou"].append(train_iou)
        history["val_iou"].append(val_iou)

        print(
            f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
            f"Train Dice: {train_dice:.4f} | Val Dice: {val_dice:.4f} | "
            f"Train IoU: {train_iou:.4f} | Val IoU: {val_iou:.4f}"
        )

        if val_dice > best_dice:
            best_dice = val_dice
            best_loss = val_loss
            torch.save(model.state_dict(), save_path)
            print(f"✅ Saved best model: {save_path} (Val Dice: {best_dice:.4f})")

    print(f"\nBest Val Dice for {model_name}: {best_dice:.4f} (Loss: {best_loss:.4f})")
    return model, history

# %%
# thay thế
# Cell fix môi trường: khôi phục NumPy + Matplotlib tương thích (xử lý lỗi _ARRAY_API / multiarray)

# !pip install -q --force-reinstall "numpy>=2.0.0,<2.3.0" "matplotlib>=3.8.0,<3.10.0"

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

print("NumPy version:", np.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.2/355.2 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 79.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 96.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# s3fs 2025.3.0 requires fsspec==2025.3.0.*, but you have fsspec 2025.10.0 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.
# gradio 5.38.1 requires pillow<12.0,>=8.0, but you have pillow 12.0.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# NumPy version: 1.26.4
# Matplotlib version: 3.7.2

# %% [markdown]
# # Cell 8: Huấn luyện mô hình dùng encoder SegFormer-B3 (mit_b3) + plot train/val Loss, Dice, IoU (no augmentation)

# %%
import gc
import matplotlib.pyplot as plt

# Cấu hình nhẹ cho SegFormer-B3 (mit_b3 encoder)
CFG.BATCH_SIZE = 2   # nếu OOM thì giảm xuống 1
torch.cuda.empty_cache()
gc.collect()

# Mô hình: dùng kiến trúc Unet với encoder SegFormer-B3 (mit_b3)
# Đây là "SegFormer-guided encoder" hợp với SMP + timm trên Kaggle.
model_segformer = smp.Unet(
    encoder_name="mit_b3",          # SegFormer-B3 encoder
    encoder_weights="imagenet",     # dùng weight pretrained
    in_channels=3,
    classes=1,
)

# Huấn luyện
model_segformer, hist_segformer = train_model(model_segformer, model_name="SegFormerB3_NoAug")

# Vẽ biểu đồ
epochs = range(1, len(hist_segformer["train_loss"]) + 1)

plt.figure(figsize=(15,4))

# (1) Loss
plt.subplot(1,3,1)
plt.plot(epochs, hist_segformer["train_loss"], label="Train Loss")
plt.plot(epochs, hist_segformer["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Val Loss (SegFormer-B3 encoder)")
plt.legend()
plt.grid(alpha=0.3)

# (2) Dice
plt.subplot(1,3,2)
plt.plot(epochs, hist_segformer["train_dice"], label="Train Dice")
plt.plot(epochs, hist_segformer["val_dice"], label="Val Dice")
plt.xlabel("Epoch")
plt.ylabel("Dice")
plt.title("Train vs Val Dice (SegFormer-B3 encoder)")
plt.legend()
plt.grid(alpha=0.3)

# (3) IoU
plt.subplot(1,3,3)
plt.plot(epochs, hist_segformer["train_iou"], label="Train IoU")
plt.plot(epochs, hist_segformer["val_iou"], label="Val IoU")
plt.xlabel("Epoch")
plt.ylabel("IoU")
plt.title("Train vs Val IoU (SegFormer-B3 encoder)")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/178M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ===== SegFormerB3_NoAug | Epoch 1/80 =====
# Train Loss: 1.2482 | Val Loss: 1.0861 | Train Dice: 0.5571 | Val Dice: 0.7107 | Train IoU: 0.4398 | Val IoU: 0.6062
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.7107)
#
# ===== SegFormerB3_NoAug | Epoch 2/80 =====
# Train Loss: 0.9854 | Val Loss: 0.9144 | Train Dice: 0.7142 | Val Dice: 0.7234 | Train IoU: 0.5954 | Val IoU: 0.6126
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.7234)
#
# ===== SegFormerB3_NoAug | Epoch 3/80 =====
# Train Loss: 0.8086 | Val Loss: 0.7728 | Train Dice: 0.7348 | Val Dice: 0.7741 | Train IoU: 0.6245 | Val IoU: 0.6790
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.7741)
#
# ===== SegFormerB3_NoAug | Epoch 4/80 =====
# Train Loss: 0.6205 | Val Loss: 0.5367 | Train Dice: 0.7969 | Val Dice: 0.7722 | Train IoU: 0.7007 | Val IoU: 0.6769
#
# ===== SegFormerB3_NoAug | Epoch 5/80 =====
# Train Loss: 0.4538 | Val Loss: 0.4136 | Train Dice: 0.8289 | Val Dice: 0.8242 | Train IoU: 0.7412 | Val IoU: 0.7394
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8242)
#
# ===== SegFormerB3_NoAug | Epoch 6/80 =====
# Train Loss: 0.3106 | Val Loss: 0.2979 | Train Dice: 0.8609 | Val Dice: 0.8098 | Train IoU: 0.7824 | Val IoU: 0.7139
#
# ===== SegFormerB3_NoAug | Epoch 7/80 =====
# Train Loss: 0.2358 | Val Loss: 0.2215 | Train Dice: 0.8614 | Val Dice: 0.8451 | Train IoU: 0.7854 | Val IoU: 0.7684
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8451)
#
# ===== SegFormerB3_NoAug | Epoch 8/80 =====
# Train Loss: 0.1916 | Val Loss: 0.2371 | Train Dice: 0.8763 | Val Dice: 0.8199 | Train IoU: 0.8054 | Val IoU: 0.7366
#
# ===== SegFormerB3_NoAug | Epoch 9/80 =====
# Train Loss: 0.1575 | Val Loss: 0.2046 | Train Dice: 0.8906 | Val Dice: 0.8309 | Train IoU: 0.8252 | Val IoU: 0.7526
#
# ===== SegFormerB3_NoAug | Epoch 10/80 =====
# Train Loss: 0.1382 | Val Loss: 0.1745 | Train Dice: 0.9002 | Val Dice: 0.8522 | Train IoU: 0.8391 | Val IoU: 0.7766
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8522)
#
# ===== SegFormerB3_NoAug | Epoch 11/80 =====
# Train Loss: 0.1221 | Val Loss: 0.1715 | Train Dice: 0.9133 | Val Dice: 0.8521 | Train IoU: 0.8569 | Val IoU: 0.7788
#
# ===== SegFormerB3_NoAug | Epoch 12/80 =====
# Train Loss: 0.1147 | Val Loss: 0.1797 | Train Dice: 0.9155 | Val Dice: 0.8436 | Train IoU: 0.8607 | Val IoU: 0.7673
#
# ===== SegFormerB3_NoAug | Epoch 13/80 =====
# Train Loss: 0.1222 | Val Loss: 0.1814 | Train Dice: 0.9054 | Val Dice: 0.8390 | Train IoU: 0.8471 | Val IoU: 0.7583
#
# ===== SegFormerB3_NoAug | Epoch 14/80 =====
# Train Loss: 0.1056 | Val Loss: 0.1668 | Train Dice: 0.9187 | Val Dice: 0.8526 | Train IoU: 0.8663 | Val IoU: 0.7768
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8526)
#
# ===== SegFormerB3_NoAug | Epoch 15/80 =====
# Train Loss: 0.0966 | Val Loss: 0.1560 | Train Dice: 0.9239 | Val Dice: 0.8598 | Train IoU: 0.8754 | Val IoU: 0.7879
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8598)
#
# ===== SegFormerB3_NoAug | Epoch 16/80 =====
# Train Loss: 0.0918 | Val Loss: 0.1603 | Train Dice: 0.9321 | Val Dice: 0.8585 | Train IoU: 0.8858 | Val IoU: 0.7852
#
# ===== SegFormerB3_NoAug | Epoch 17/80 =====
# Train Loss: 0.0950 | Val Loss: 0.1653 | Train Dice: 0.9282 | Val Dice: 0.8520 | Train IoU: 0.8798 | Val IoU: 0.7787
#
# ===== SegFormerB3_NoAug | Epoch 18/80 =====
# Train Loss: 0.0901 | Val Loss: 0.1519 | Train Dice: 0.9283 | Val Dice: 0.8683 | Train IoU: 0.8823 | Val IoU: 0.7970
# ✅ Saved best model: SegFormerB3_NoAug_best_no_aug.pth (Val Dice: 0.8683)
#
# ===== SegFormerB3_NoAug | Epoch 19/80 =====
# Train Loss: 0.0836 | Val Loss: 0.1589 | Train Dice: 0.9372 | Val Dice: 0.8572 | Train IoU: 0.8948 | Val IoU: 0.7843
#
# ===== SegFormerB3_NoAug | Epoch 20/80 =====
# Train Loss: 0.0843 | Val Loss: 0.1584 | Train Dice: 0.9361 | Val Dice: 0.8578 | Train IoU: 0.8928 | Val IoU: 0.7846
#
# ===== SegFormerB3_NoAug | Epoch 21/80 =====
# Train Loss: 0.0815 | Val Loss: 0.1641 | Train Dice: 0.9371 | Val Dice: 0.8506 | Train IoU: 0.8956 | Val IoU: 0.7767
#
# ===== SegFormerB3_NoAug | Epoch 22/80 =====
# Train Loss: 0.0950 | Val Loss: 0.2185 | Train Dice: 0.9262 | Val Dice: 0.8102 | Train IoU: 0.8802 | Val IoU: 0.7251
#
# ===== SegFormerB3_NoAug | Epoch 23/80 =====
# Train Loss: 0.1559 | Val Loss: 0.1652 | Train Dice: 0.8710 | Val Dice: 0.8554 | Train IoU: 0.8028 | Val IoU: 0.7804
#
# ===== SegFormerB3_NoAug | Epoch 24/80 =====
# Train Loss: 0.0992 | Val Loss: 0.1561 | Train Dice: 0.9173 | Val Dice: 0.8583 | Train IoU: 0.8677 | Val IoU: 0.7856
#
# ===== SegFormerB3_NoAug | Epoch 25/80 =====
# Train Loss: 0.0806 | Val Loss: 0.1560 | Train Dice: 0.9375 | Val Dice: 0.8587 | Train IoU: 0.8963 | Val IoU: 0.7869
#
# ===== SegFormerB3_NoAug | Epoch 26/80 =====
# Train Loss: 0.0752 | Val Loss: 0.1587 | Train Dice: 0.9411 | Val Dice: 0.8561 | Train IoU: 0.9031 | Val IoU: 0.7846
#
# ===== SegFormerB3_NoAug | Epoch 27/80 =====
# Train Loss: 0.0722 | Val Loss: 0.1554 | Train Dice: 0.9449 | Val Dice: 0.8594 | Train IoU: 0.9089 | Val IoU: 0.7883
#
# ===== SegFormerB3_NoAug | Epoch 28/80 =====
# Train Loss: 0.0700 | Val Loss: 0.1580 | Train Dice: 0.9480 | Val Dice: 0.8569 | Train IoU: 0.9134 | Val IoU: 0.7855
#
# ===== SegFormerB3_NoAug | Epoch 29/80 =====
# Train Loss: 0.0691 | Val Loss: 0.1574 | Train Dice: 0.9499 | Val Dice: 0.8576 | Train IoU: 0.9159 | Val IoU: 0.7863
#
# ===== SegFormerB3_NoAug | Epoch 30/80 =====
# Train Loss: 0.0674 | Val Loss: 0.1565 | Train Dice: 0.9513 | Val Dice: 0.8581 | Train IoU: 0.9185 | Val IoU: 0.7863
#
# ===== SegFormerB3_NoAug | Epoch 31/80 =====
# Train Loss: 0.0659 | Val Loss: 0.1571 | Train Dice: 0.9526 | Val Dice: 0.8583 | Train IoU: 0.9209 | Val IoU: 0.7873
#
# ===== SegFormerB3_NoAug | Epoch 32/80 =====
# Train Loss: 0.0650 | Val Loss: 0.1581 | Train Dice: 0.9510 | Val Dice: 0.8573 | Train IoU: 0.9208 | Val IoU: 0.7860
#
# ===== SegFormerB3_NoAug | Epoch 33/80 =====
# Train Loss: 0.0633 | Val Loss: 0.1583 | Train Dice: 0.9563 | Val Dice: 0.8565 | Train IoU: 0.9265 | Val IoU: 0.7849
#
# ===== SegFormerB3_NoAug | Epoch 34/80 =====
# Train Loss: 0.0628 | Val Loss: 0.1584 | Train Dice: 0.9554 | Val Dice: 0.8568 | Train IoU: 0.9258 | Val IoU: 0.7856
#
# ===== SegFormerB3_NoAug | Epoch 35/80 =====
# Train Loss: 0.0632 | Val Loss: 0.1590 | Train Dice: 0.9549 | Val Dice: 0.8562 | Train IoU: 0.9260 | Val IoU: 0.7845
#
# ===== SegFormerB3_NoAug | Epoch 36/80 =====
# Train Loss: 0.0616 | Val Loss: 0.1586 | Train Dice: 0.9563 | Val Dice: 0.8570 | Train IoU: 0.9276 | Val IoU: 0.7853
#
# ===== SegFormerB3_NoAug | Epoch 37/80 =====
# Train Loss: 0.0608 | Val Loss: 0.1594 | Train Dice: 0.9559 | Val Dice: 0.8562 | Train IoU: 0.9278 | Val IoU: 0.7846
#
# ===== SegFormerB3_NoAug | Epoch 38/80 =====
# Train Loss: 0.0595 | Val Loss: 0.1595 | Train Dice: 0.9596 | Val Dice: 0.8559 | Train IoU: 0.9326 | Val IoU: 0.7840
#
# ===== SegFormerB3_NoAug | Epoch 39/80 =====
# Train Loss: 0.0587 | Val Loss: 0.1605 | Train Dice: 0.9614 | Val Dice: 0.8556 | Train IoU: 0.9349 | Val IoU: 0.7838
#
# ===== SegFormerB3_NoAug | Epoch 40/80 =====
# Train Loss: 0.0587 | Val Loss: 0.1600 | Train Dice: 0.9640 | Val Dice: 0.8561 | Train IoU: 0.9376 | Val IoU: 0.7842
#
# ===== SegFormerB3_NoAug | Epoch 41/80 =====
# Train Loss: 0.0582 | Val Loss: 0.1608 | Train Dice: 0.9619 | Val Dice: 0.8548 | Train IoU: 0.9358 | Val IoU: 0.7828
#
# ===== SegFormerB3_NoAug | Epoch 42/80 =====
# Train Loss: 0.0578 | Val Loss: 0.1624 | Train Dice: 0.9634 | Val Dice: 0.8539 | Train IoU: 0.9376 | Val IoU: 0.7808
#
# ===== SegFormerB3_NoAug | Epoch 43/80 =====
# Train Loss: 0.0577 | Val Loss: 0.1601 | Train Dice: 0.9623 | Val Dice: 0.8560 | Train IoU: 0.9366 | Val IoU: 0.7836
#
# ===== SegFormerB3_NoAug | Epoch 44/80 =====
# Train Loss: 0.0567 | Val Loss: 0.1609 | Train Dice: 0.9644 | Val Dice: 0.8555 | Train IoU: 0.9395 | Val IoU: 0.7834
#
# ===== SegFormerB3_NoAug | Epoch 45/80 =====
# Train Loss: 0.0564 | Val Loss: 0.1614 | Train Dice: 0.9635 | Val Dice: 0.8551 | Train IoU: 0.9388 | Val IoU: 0.7828
#
# ===== SegFormerB3_NoAug | Epoch 46/80 =====
# Train Loss: 0.0561 | Val Loss: 0.1617 | Train Dice: 0.9638 | Val Dice: 0.8543 | Train IoU: 0.9393 | Val IoU: 0.7817
#
# ===== SegFormerB3_NoAug | Epoch 47/80 =====
# Train Loss: 0.0561 | Val Loss: 0.1616 | Train Dice: 0.9663 | Val Dice: 0.8546 | Train IoU: 0.9419 | Val IoU: 0.7822
#
# ===== SegFormerB3_NoAug | Epoch 48/80 =====
# Train Loss: 0.0559 | Val Loss: 0.1616 | Train Dice: 0.9665 | Val Dice: 0.8544 | Train IoU: 0.9422 | Val IoU: 0.7819
#
# ===== SegFormerB3_NoAug | Epoch 49/80 =====
# Train Loss: 0.0554 | Val Loss: 0.1618 | Train Dice: 0.9657 | Val Dice: 0.8544 | Train IoU: 0.9418 | Val IoU: 0.7819
#
# ===== SegFormerB3_NoAug | Epoch 50/80 =====
# Train Loss: 0.0566 | Val Loss: 0.1623 | Train Dice: 0.9632 | Val Dice: 0.8544 | Train IoU: 0.9393 | Val IoU: 0.7818
#
# ===== SegFormerB3_NoAug | Epoch 51/80 =====
# Train Loss: 0.0550 | Val Loss: 0.1615 | Train Dice: 0.9635 | Val Dice: 0.8545 | Train IoU: 0.9400 | Val IoU: 0.7821
#
# ===== SegFormerB3_NoAug | Epoch 52/80 =====
# Train Loss: 0.0562 | Val Loss: 0.1622 | Train Dice: 0.9648 | Val Dice: 0.8543 | Train IoU: 0.9411 | Val IoU: 0.7818
#
# ===== SegFormerB3_NoAug | Epoch 53/80 =====
# Train Loss: 0.0548 | Val Loss: 0.1621 | Train Dice: 0.9650 | Val Dice: 0.8545 | Train IoU: 0.9415 | Val IoU: 0.7821
#
# ===== SegFormerB3_NoAug | Epoch 54/80 =====
# Train Loss: 0.0548 | Val Loss: 0.1616 | Train Dice: 0.9662 | Val Dice: 0.8544 | Train IoU: 0.9428 | Val IoU: 0.7820
#
# ===== SegFormerB3_NoAug | Epoch 55/80 =====
# Train Loss: 0.0545 | Val Loss: 0.1624 | Train Dice: 0.9664 | Val Dice: 0.8542 | Train IoU: 0.9432 | Val IoU: 0.7816
#
# ===== SegFormerB3_NoAug | Epoch 56/80 =====
# Train Loss: 0.0545 | Val Loss: 0.1622 | Train Dice: 0.9641 | Val Dice: 0.8544 | Train IoU: 0.9409 | Val IoU: 0.7819
#
# ===== SegFormerB3_NoAug | Epoch 57/80 =====
# Train Loss: 0.0544 | Val Loss: 0.1622 | Train Dice: 0.9666 | Val Dice: 0.8542 | Train IoU: 0.9434 | Val IoU: 0.7816
#
# ===== SegFormerB3_NoAug | Epoch 58/80 =====
# Train Loss: 0.0543 | Val Loss: 0.1621 | Train Dice: 0.9666 | Val Dice: 0.8542 | Train IoU: 0.9435 | Val IoU: 0.7817
#
# ===== SegFormerB3_NoAug | Epoch 59/80 =====
# Train Loss: 0.0546 | Val Loss: 0.1621 | Train Dice: 0.9663 | Val Dice: 0.8543 | Train IoU: 0.9430 | Val IoU: 0.7819
#
# ===== SegFormerB3_NoAug | Epoch 60/80 =====
# Train Loss: 0.0541 | Val Loss: 0.1629 | Train Dice: 0.9668 | Val Dice: 0.8540 | Train IoU: 0.9439 | Val IoU: 0.7815
#
# ===== SegFormerB3_NoAug | Epoch 61/80 =====
# Train Loss: 0.0542 | Val Loss: 0.1625 | Train Dice: 0.9666 | Val Dice: 0.8541 | Train IoU: 0.9436 | Val IoU: 0.7815
#
# ===== SegFormerB3_NoAug | Epoch 62/80 =====
# Train Loss: 0.0541 | Val Loss: 0.1626 | Train Dice: 0.9668 | Val Dice: 0.8540 | Train IoU: 0.9439 | Val IoU: 0.7813
#
# ===== SegFormerB3_NoAug | Epoch 63/80 =====
# Train Loss: 0.0540 | Val Loss: 0.1626 | Train Dice: 0.9657 | Val Dice: 0.8539 | Train IoU: 0.9430 | Val IoU: 0.7813
#
# ===== SegFormerB3_NoAug | Epoch 64/80 =====
# Train Loss: 0.0540 | Val Loss: 0.1623 | Train Dice: 0.9657 | Val Dice: 0.8539 | Train IoU: 0.9428 | Val IoU: 0.7811
#
# ===== SegFormerB3_NoAug | Epoch 65/80 =====
# Train Loss: 0.0538 | Val Loss: 0.1624 | Train Dice: 0.9646 | Val Dice: 0.8538 | Train IoU: 0.9419 | Val IoU: 0.7811
#
# ===== SegFormerB3_NoAug | Epoch 66/80 =====
# Train Loss: 0.0538 | Val Loss: 0.1625 | Train Dice: 0.9647 | Val Dice: 0.8540 | Train IoU: 0.9421 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 67/80 =====
# Train Loss: 0.0542 | Val Loss: 0.1630 | Train Dice: 0.9679 | Val Dice: 0.8541 | Train IoU: 0.9451 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 68/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1625 | Train Dice: 0.9672 | Val Dice: 0.8540 | Train IoU: 0.9447 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 69/80 =====
# Train Loss: 0.0539 | Val Loss: 0.1624 | Train Dice: 0.9658 | Val Dice: 0.8540 | Train IoU: 0.9432 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 70/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1623 | Train Dice: 0.9672 | Val Dice: 0.8541 | Train IoU: 0.9446 | Val IoU: 0.7815
#
# ===== SegFormerB3_NoAug | Epoch 71/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1624 | Train Dice: 0.9672 | Val Dice: 0.8539 | Train IoU: 0.9447 | Val IoU: 0.7812
#
# ===== SegFormerB3_NoAug | Epoch 72/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1627 | Train Dice: 0.9672 | Val Dice: 0.8536 | Train IoU: 0.9446 | Val IoU: 0.7808
#
# ===== SegFormerB3_NoAug | Epoch 73/80 =====
# Train Loss: 0.0536 | Val Loss: 0.1623 | Train Dice: 0.9673 | Val Dice: 0.8540 | Train IoU: 0.9448 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 74/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1632 | Train Dice: 0.9672 | Val Dice: 0.8540 | Train IoU: 0.9447 | Val IoU: 0.7813
#
# ===== SegFormerB3_NoAug | Epoch 75/80 =====
# Train Loss: 0.0536 | Val Loss: 0.1631 | Train Dice: 0.9685 | Val Dice: 0.8538 | Train IoU: 0.9461 | Val IoU: 0.7811
#
# ===== SegFormerB3_NoAug | Epoch 76/80 =====
# Train Loss: 0.0537 | Val Loss: 0.1626 | Train Dice: 0.9672 | Val Dice: 0.8540 | Train IoU: 0.9447 | Val IoU: 0.7814
#
# ===== SegFormerB3_NoAug | Epoch 77/80 =====
# Train Loss: 0.0536 | Val Loss: 0.1625 | Train Dice: 0.9686 | Val Dice: 0.8540 | Train IoU: 0.9461 | Val IoU: 0.7813
#
# ===== SegFormerB3_NoAug | Epoch 78/80 =====
# Train Loss: 0.0535 | Val Loss: 0.1626 | Train Dice: 0.9661 | Val Dice: 0.8543 | Train IoU: 0.9437 | Val IoU: 0.7817
#
# ===== SegFormerB3_NoAug | Epoch 79/80 =====
# Train Loss: 0.0539 | Val Loss: 0.1624 | Train Dice: 0.9681 | Val Dice: 0.8539 | Train IoU: 0.9453 | Val IoU: 0.7811
#
# ===== SegFormerB3_NoAug | Epoch 80/80 =====
# Train Loss: 0.0539 | Val Loss: 0.1625 | Train Dice: 0.9670 | Val Dice: 0.8540 | Train IoU: 0.9442 | Val IoU: 0.7813
#
# Best Val Dice for SegFormerB3_NoAug: 0.8683 (Loss: 0.1519)
